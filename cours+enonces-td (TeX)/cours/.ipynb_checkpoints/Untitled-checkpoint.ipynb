# %%
t = float(input("Quelle est la temperature? "))

print(str(t), "C =", (9/5)*t + 32 , "F")
print(str(t), "F =", (t - 32)*5/9 , "C")
# Out:
# Quelle est la temperature? 20.2
# 20.2 C = 68.36 F
# 20.2 F = -6.555555555555555 C

# %%
chaine = "abc"
for x in chaine:
    print(x)
    print("instruction suivante")
print("FIN")
# Out:
# a
# instruction suivante
# b
# instruction suivante
# c
# instruction suivante
# FIN

# %%
chaine[2:6]
# Out:
# 'cdef'

# %%
texte = "We introduce here the Python language"
compteur = 0
for c in texte:
    if c != " ":
        compteur += 1
print(compteur)
# Out:
# 32

# %%
compteur = 0
for c in texte:
    if c != " ":
        compteur += 1
print(compteur)
